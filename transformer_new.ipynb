# %%
import pandas as pd
new_data = pd.read_csv("data/updated_counts_avg_max_severity_dataset.csv")
original_data = pd.read_csv("data/updated_counts_severity_dataset.csv")

# %%
original_data.head()
# Out:
#                   artist_all                artist_base  rank  \
# 0         the isley brothers         the isley brothers  27.0
# 1  prince and the revolution  prince and the revolution  21.0
# 2                        emf                        emf   6.0
# 3                      tesla                      tesla  73.0
# 4              sir mix-a-lot              sir mix-a-lot   2.0
#
#               song    year artist_featured       song_clean  \
# 0  fight the power  1975.0             NaN  fight the power
# 1   let's go crazy  1984.0             NaN    lets go crazy
# 2     unbelievable  1991.0             NaN     unbelievable
# 3            signs  1991.0             NaN            signs
# 4    baby got back  1992.0             NaN    baby got back
#
#                 artist_clean  \
# 0         the isley brothers
# 1  prince and the revolution
# 2                        emf
# 3                      tesla
# 4              sir mix a lot
#
# ...

# %%
new_data.head()
# Out:
#                                               lyrics  acousticness  \
# 0  I see it in your eyes You're seconds from dest...       0.28800
# 1  Master P: (Chorus)(3X) Mama always told me (to...       0.02020
# 2  If I told you, that this couldn't get better b...       0.00262
# 3  I feel your love I feel time is up When I was ...       0.74700
# 4  Don't know when it started and I don't know wh...       0.00306
#
#    danceability  energy  instrumentalness  loudness  speechiness    tempo  \
# 0         0.466   0.585          0.000000    -5.347       0.0432  126.054
# 1         0.692   0.551          0.000000    -8.252       0.2480  163.932
# 2         0.725   0.874          0.000412    -3.715       0.0396  127.985
# 3         0.732   0.408          0.000229    -8.475       0.0360   87.016
# 4         0.871   0.531          0.213000    -9.373       0.0473  123.978
#
#    valence  explicit  ...  mental_slurs_max_severity  \
# 0    0.289     False  ...                   0.254769
# ...

# %%
import torch
trans_model = torch.load("transformer_model.pth")
# Out:
# C:\Users\ziyue\AppData\Local\Temp\ipykernel_25988\1671887894.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   trans_model = torch.load("transformer_model.pth")
# ...
