# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import mutual_info_classif
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.impute import SimpleImputer
from scipy.sparse import hstack
import matplotlib.pyplot as plt
import seaborn as sns

# Load the updated dataset
df = pd.read_csv("data/updated_counts_avg_max_severity_dataset_main.csv")

# Define features for analysis
category_count_features = [
    "violence_content_count", "drug_content_count", "hate_speech_content_count", 
    "profanity_content_count", "mental_slurs_content_count", "religious_slurs_content_count", 
    "racial_slurs_content_count", "sexual_content_content_count"
]
category_severity_features = [
    "violence_avg_severity", "drug_avg_severity", "hate_speech_avg_severity", 
    "profanity_avg_severity", "mental_slurs_avg_severity", "religious_slurs_avg_severity", 
    "racial_slurs_avg_severity", "sexual_content_avg_severity"
]

category_max_features = [
    "violence_max_severity", "drug_max_severity", "hate_speech_max_severity", 
    "profanity_max_severity", "mental_slurs_max_severity", "religious_slurs_max_severity", 
    "racial_slurs_max_severity", "sexual_content_max_severity"
]

numerical_features = [
    # Audio features
    "acousticness",
    "danceability", 
    "energy",
    "instrumentalness",
    "loudness",
    "speechiness",
    "tempo",
    "valence",
]

# %%
# Combine features for modeling
all_features = category_severity_features + numerical_features + category_max_features
# all_features = category_max_features
X_numerical = df[all_features]

#imputer = SimpleImputer(strategy='mean')
#X_numerical_imputed = imputer.fit_transform(X_numerical)

# Convert back to DataFrame to keep feature names
X_numerical_clean = pd.DataFrame(X_numerical_imputed, columns=all_features)

# X_numerical = df[category_max_features]
y = df["explicit"]  # Target variable

# %%
# Step 1: Convert lyrics to numerical representation using TF-IDF
tfidf = TfidfVectorizer(max_features=5000)  # Limit to the top 5000 most important words
X_text = tfidf.fit_transform(df["lyrics"])  # Transform the lyrics into TF-IDF features

# Combine TF-IDF text features with numerical features
X_combined = hstack([X_text, X_numerical])  # Combine text and numerical features
#X_combined = X_numerical_clean
#X_combined = X_text

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_combined, y, test_size=0.2, random_state=42, stratify=y)

# %%
# Step 2: Analyze Explicitness Ratios by Count and Severity
category_ratios = {}
for category in category_count_features + category_severity_features:
    ratio = df[df[category] > 0]["explicit"].mean()
    category_ratios[category] = ratio

# Convert to DataFrame for visualization
category_ratios_df = pd.DataFrame({
    "Category": category_ratios.keys(),
    "Explicit Ratio": category_ratios.values()
}).sort_values(by="Explicit Ratio", ascending=False)

# Visualize explicitness ratios
plt.figure(figsize=(12, 8))
sns.barplot(data=category_ratios_df, x="Explicit Ratio", y="Category", palette="rocket")
plt.title("Explicitness Ratio by Category", fontsize=16)
plt.xlabel("Explicitness Ratio", fontsize=14)
plt.ylabel("Category", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ziyue\AppData\Local\Temp\ipykernel_27584\3908411142.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=category_ratios_df, x="Explicit Ratio", y="Category", palette="rocket")

# %%
# Step 3: Train a Random Forest Classifier
rf_model = RandomForestClassifier(random_state=42, n_estimators=100)
rf_model.fit(X_train, y_train)

# Predictions and evaluation
y_pred_rf = rf_model.predict(X_test)
print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Classification Report:\n", classification_report(y_test, y_pred_rf))

# Confusion Matrix
rf_cm = confusion_matrix(y_test, y_pred_rf)
sns.heatmap(rf_cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix - Random Forest", fontsize=16)
plt.xlabel("Predicted", fontsize=14)
plt.ylabel("True", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Random Forest Accuracy: 0.9095052083333334
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.91      0.96      0.93      1023
#         True       0.92      0.80      0.86       513
#
#     accuracy                           0.91      1536
#    macro avg       0.91      0.88      0.89      1536
# weighted avg       0.91      0.91      0.91      1536

# %%
# Step 4: Analyze Feature Importance
mutual_info = mutual_info_classif(X_numerical_clean, y, random_state=42)
feature_importance = pd.DataFrame({
    "Feature": all_features,
    "Importance": mutual_info
}).sort_values(by="Importance", ascending=False)

# Visualize Feature Importance
plt.figure(figsize=(12, 8))
sns.barplot(data=feature_importance, x="Importance", y="Feature", palette="viridis")
plt.title("Feature Importance Based on Mutual Information", fontsize=16)
plt.xlabel("Importance", fontsize=14)
plt.ylabel("Feature", fontsize=14)
plt.tight_layout()
plt.savefig("Feature Importance Based on Mutual Information.jpg")
plt.show()
# Out:
# C:\Users\ziyue\AppData\Local\Temp\ipykernel_27584\550406045.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=feature_importance, x="Importance", y="Feature", palette="viridis")

# %%
# Step 5: Evaluate Explicitness Ratios at Different Severity Thresholds
severity_thresholds = [0.2, 0.4, 0.6, 0.8]  # Example thresholds
severity_ratios = {category: [] for category in category_severity_features}
severity_counts = {category: [] for category in category_severity_features}

for threshold in severity_thresholds:
    print(f"\n--- Severity Threshold: {threshold} ---")
    for category in category_severity_features:
        # Filter by threshold
        filtered_songs = df[df[category] > threshold]
        explicit_count = filtered_songs["explicit"].sum()
        non_explicit_count = len(filtered_songs) - explicit_count
        
        if len(filtered_songs) > 0:
            ratio = explicit_count / len(filtered_songs)
        else:
            ratio = 0
        
        severity_ratios[category].append(ratio)
        severity_counts[category].append((explicit_count, non_explicit_count))
        
        # Print counts
        print(f"Category: {category}")
        print(f"  Explicit: {explicit_count}")
        print(f"  Non-Explicit: {non_explicit_count}")
        print(f"  Explicitness Ratio: {ratio:.4f}")

# Convert severity ratios to DataFrame for visualization
severity_ratios_df = pd.DataFrame(severity_ratios, index=severity_thresholds).reset_index()
severity_ratios_df = severity_ratios_df.melt(id_vars="index", var_name="Category", value_name="Explicitness Ratio")
severity_ratios_df.rename(columns={"index": "Severity Threshold"}, inplace=True)

# Initialize dictionaries to store ratios and counts for category_max_features
max_ratios = {category: [] for category in category_max_features}
max_counts = {category: [] for category in category_max_features}

# Analysis for category_max_features
for threshold in severity_thresholds:
    print(f"\n--- Max Severity Threshold: {threshold} ---")
    for category in category_max_features:
        # Filter by threshold
        filtered_songs = df[df[category] > threshold]
        explicit_count = filtered_songs["explicit"].sum()
        non_explicit_count = len(filtered_songs) - explicit_count

        if len(filtered_songs) > 0:
            ratio = explicit_count / len(filtered_songs)
        else:
            ratio = 0

        max_ratios[category].append(ratio)
        max_counts[category].append((explicit_count, non_explicit_count))

        # Print counts
        print(f"Category: {category}")
        print(f"  Explicit: {explicit_count}")
        print(f"  Non-Explicit: {non_explicit_count}")
        print(f"  Explicitness Ratio: {ratio:.4f}")

# Visualization for category_max_features
max_ratios_df = pd.DataFrame(max_ratios, index=severity_thresholds).reset_index()
max_ratios_df = max_ratios_df.melt(id_vars="index", var_name="Category", value_name="Explicitness Ratio")
max_ratios_df.rename(columns={"index": "Max Severity Threshold"}, inplace=True)

# Plot severity threshold analysis
plt.figure(figsize=(12, 8))
sns.lineplot(data=severity_ratios_df, x="Severity Threshold", y="Explicitness Ratio", hue="Category", marker="o")
plt.title("Explicitness Ratio by Severity Threshold", fontsize=16)
plt.xlabel("Severity Threshold", fontsize=14)
plt.ylabel("Explicitness Ratio", fontsize=14)
plt.legend(title="Category", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.savefig("Explicitness Ratio by Severity Threshold.jpg")
plt.show()

# Plot max severity threshold analysis
plt.figure(figsize=(12, 8))
sns.lineplot(data=max_ratios_df, x="Max Severity Threshold", y="Explicitness Ratio", hue="Category", marker="o")
plt.title("Explicitness Ratio by Max Severity Threshold", fontsize=16)
plt.xlabel("Max Severity Threshold", fontsize=14)
plt.ylabel("Explicitness Ratio", fontsize=14)
plt.legend(title="Category", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.savefig("Explicitness Ratio by Severity Threshold.jpg")
plt.show()
# Out:
# --- Severity Threshold: 0.2 ---
# Category: violence_avg_severity
#   Explicit: 270
#   Non-Explicit: 61
#   Explicitness Ratio: 0.8157
# Category: drug_avg_severity
#   Explicit: 259
#   Non-Explicit: 124
#   Explicitness Ratio: 0.6762
# Category: hate_speech_avg_severity
#   Explicit: 1433
#   Non-Explicit: 234
#   Explicitness Ratio: 0.8596
# Category: profanity_avg_severity
#   Explicit: 1276
#   Non-Explicit: 240
#   Explicitness Ratio: 0.8417
# Category: mental_slurs_avg_severity
#   Explicit: 460
#   Non-Explicit: 110
#   Explicitness Ratio: 0.8070
# Category: religious_slurs_avg_severity
#   Explicit: 345
#   Non-Explicit: 239
#   Explicitness Ratio: 0.5908
# Category: racial_slurs_avg_severity
#   Explicit: 1245
#   Non-Explicit: 584
#   Explicitness Ratio: 0.6807
# Category: sexual_content_avg_severity
#   Explicit: 863
#   Non-Explicit: 211
#   Explicitness Ratio: 0.8035
#
# --- Severity Threshold: 0.4 ---
# Category: violence_avg_severity
#   Explicit: 27
#   Non-Explicit: 7
#   Explicitness Ratio: 0.7941
# Category: drug_avg_severity
#   Explicit: 38
#   Non-Explicit: 14
#   Explicitness Ratio: 0.7308
# Category: hate_speech_avg_severity
#   Explicit: 620
#   Non-Explicit: 58
#   Explicitness Ratio: 0.9145
# Category: profanity_avg_severity
#   Explicit: 382
#   Non-Explicit: 46
#   Explicitness Ratio: 0.8925
# Category: mental_slurs_avg_severity
#   Explicit: 40
#   Non-Explicit: 8
#   Explicitness Ratio: 0.8333
# Category: religious_slurs_avg_severity
#   Explicit: 281
#   Non-Explicit: 159
#   Explicitness Ratio: 0.6386
# Category: racial_slurs_avg_severity
#   Explicit: 797
#   Non-Explicit: 279
#   Explicitness Ratio: 0.7407
# Category: sexual_content_avg_severity
#   Explicit: 225
#   Non-Explicit: 39
#   Explicitness Ratio: 0.8523
#
# --- Severity Threshold: 0.6 ---
# Category: violence_avg_severity
#   Explicit: 3
#   Non-Explicit: 2
#   Explicitness Ratio: 0.6000
# Category: drug_avg_severity
#   Explicit: 5
#   Non-Explicit: 8
#   Explicitness Ratio: 0.3846
# Category: hate_speech_avg_severity
#   Explicit: 150
#   Non-Explicit: 11
#   Explicitness Ratio: 0.9317
# Category: profanity_avg_severity
#   Explicit: 72
#   Non-Explicit: 12
#   Explicitness Ratio: 0.8571
# Category: mental_slurs_avg_severity
#   Explicit: 10
#   Non-Explicit: 2
#   Explicitness Ratio: 0.8333
# Category: religious_slurs_avg_severity
#   Explicit: 213
#   Non-Explicit: 95
#   Explicitness Ratio: 0.6916
# Category: racial_slurs_avg_severity
#   Explicit: 365
#   Non-Explicit: 20
#   Explicitness Ratio: 0.9481
# Category: sexual_content_avg_severity
#   Explicit: 53
#   Non-Explicit: 9
#   Explicitness Ratio: 0.8548
#
# --- Severity Threshold: 0.8 ---
# Category: violence_avg_severity
#   Explicit: 0
#   Non-Explicit: 2
#   Explicitness Ratio: 0.0000
# Category: drug_avg_severity
#   Explicit: 0
#   Non-Explicit: 1
#   Explicitness Ratio: 0.0000
# Category: hate_speech_avg_severity
#   Explicit: 24
#   Non-Explicit: 4
#   Explicitness Ratio: 0.8571
# Category: profanity_avg_severity
#   Explicit: 12
#   Non-Explicit: 4
#   Explicitness Ratio: 0.7500
# Category: mental_slurs_avg_severity
#   Explicit: 0
#   Non-Explicit: 1
#   Explicitness Ratio: 0.0000
# Category: religious_slurs_avg_severity
#   Explicit: 136
#   Non-Explicit: 81
#   Explicitness Ratio: 0.6267
# Category: racial_slurs_avg_severity
#   Explicit: 121
#   Non-Explicit: 9
#   Explicitness Ratio: 0.9308
# Category: sexual_content_avg_severity
#   Explicit: 16
#   Non-Explicit: 3
#   Explicitness Ratio: 0.8421
#
# --- Max Severity Threshold: 0.2 ---
# Category: violence_max_severity
#   Explicit: 2389
#   Non-Explicit: 2872
#   Explicitness Ratio: 0.4541
# Category: drug_max_severity
#   Explicit: 1930
#   Non-Explicit: 1433
#   Explicitness Ratio: 0.5739
# Category: hate_speech_max_severity
#   Explicit: 2231
#   Non-Explicit: 1484
#   Explicitness Ratio: 0.6005
# Category: profanity_max_severity
#   Explicit: 2309
#   Non-Explicit: 1387
#   Explicitness Ratio: 0.6247
# Category: mental_slurs_max_severity
#   Explicit: 2412
#   Non-Explicit: 3005
#   Explicitness Ratio: 0.4453
# Category: religious_slurs_max_severity
#   Explicit: 350
#   Non-Explicit: 241
#   Explicitness Ratio: 0.5922
# Category: racial_slurs_max_severity
#   Explicit: 1612
#   Non-Explicit: 931
#   Explicitness Ratio: 0.6339
# Category: sexual_content_max_severity
#   Explicit: 2092
#   Non-Explicit: 1348
#   Explicitness Ratio: 0.6081
#
# --- Max Severity Threshold: 0.4 ---
# Category: violence_max_severity
#   Explicit: 2296
#   Non-Explicit: 2110
#   Explicitness Ratio: 0.5211
# Category: drug_max_severity
#   Explicit: 1725
#   Non-Explicit: 1043
#   Explicitness Ratio: 0.6232
# Category: hate_speech_max_severity
#   Explicit: 2165
#   Non-Explicit: 1242
#   Explicitness Ratio: 0.6355
# Category: profanity_max_severity
#   Explicit: 2264
#   Non-Explicit: 1114
#   Explicitness Ratio: 0.6702
# Category: mental_slurs_max_severity
#   Explicit: 2352
#   Non-Explicit: 2412
#   Explicitness Ratio: 0.4937
# Category: religious_slurs_max_severity
#   Explicit: 305
#   Non-Explicit: 171
#   Explicitness Ratio: 0.6408
# Category: racial_slurs_max_severity
#   Explicit: 1507
#   Non-Explicit: 755
#   Explicitness Ratio: 0.6662
# Category: sexual_content_max_severity
#   Explicit: 1995
#   Non-Explicit: 851
#   Explicitness Ratio: 0.7010
#
# --- Max Severity Threshold: 0.6 ---
# Category: violence_max_severity
#   Explicit: 2211
#   Non-Explicit: 1515
#   Explicitness Ratio: 0.5934
# Category: drug_max_severity
#   Explicit: 1585
#   Non-Explicit: 840
#   Explicitness Ratio: 0.6536
# Category: hate_speech_max_severity
#   Explicit: 2086
#   Non-Explicit: 547
#   Explicitness Ratio: 0.7923
# Category: profanity_max_severity
#   Explicit: 2235
#   Non-Explicit: 958
#   Explicitness Ratio: 0.7000
# Category: mental_slurs_max_severity
#   Explicit: 2232
#   Non-Explicit: 1617
#   Explicitness Ratio: 0.5799
# Category: religious_slurs_max_severity
#   Explicit: 240
#   Non-Explicit: 105
#   Explicitness Ratio: 0.6957
# Category: racial_slurs_max_severity
#   Explicit: 1257
#   Non-Explicit: 82
#   Explicitness Ratio: 0.9388
# Category: sexual_content_max_severity
#   Explicit: 1914
#   Non-Explicit: 516
#   Explicitness Ratio: 0.7877
#
# --- Max Severity Threshold: 0.8 ---
# Category: violence_max_severity
#   Explicit: 2106
#   Non-Explicit: 1139
#   Explicitness Ratio: 0.6490
# Category: drug_max_severity
#   Explicit: 1408
#   Non-Explicit: 625
#   Explicitness Ratio: 0.6926
# Category: hate_speech_max_severity
#   Explicit: 2044
#   Non-Explicit: 415
#   Explicitness Ratio: 0.8312
# Category: profanity_max_severity
#   Explicit: 2148
#   Non-Explicit: 665
#   Explicitness Ratio: 0.7636
# Category: mental_slurs_max_severity
#   Explicit: 2132
#   Non-Explicit: 1169
#   Explicitness Ratio: 0.6459
# Category: religious_slurs_max_severity
#   Explicit: 161
#   Non-Explicit: 85
#   Explicitness Ratio: 0.6545
# Category: racial_slurs_max_severity
#   Explicit: 1215
#   Non-Explicit: 62
#   Explicitness Ratio: 0.9514
# Category: sexual_content_max_severity
#   Explicit: 1843
#   Non-Explicit: 382
#   Explicitness Ratio: 0.8283
